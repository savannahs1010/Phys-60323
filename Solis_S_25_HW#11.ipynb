# %% [markdown]
# # PyObject:  Object-oriented programming HW 11

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# Copy your Particle class here

class particle(object):
    def __init__(self, x, y, z, vx, vy, vz, m):
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.m = m

    def K_E(self):
        return (0.5*(self.m) * (self.vx**2+self.vy**2+self.vz**2))
    

    def find_distance(self, object2):
        return np.sqrt((self.x-object2.x)**2 + (self.y-object2.y)**2 + (self.z-object2.z)**2)

    def new_position(self, dt):
        self.x += self.x + self.vx*dt
        self.y += self.y + self.vy*dt
        self.z += self.z + self.vz*dt
        return(self.x, self.y, self.z)
    

# part 5
class ChargedParticle(particle):
    
    def __init__(self, x, y, z, vx, vy, vz, m, charge):
    
        super().__init__(x, y, z, vx, vy, vz, m)
        # Add a new attribute for electric charge
        self.charge = charge

p1 = particle(1,2,3,0,5,0,7)
p2 = particle(7,6,0,4,3,2,0)
p3 = ChargedParticle(7,6,0,4,3,2,0,9)

# %%
# write/copy code here

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# 6. Write a method in the ChargedParticle class (above) that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here

class particle(object):
    def __init__(self, x, y, z, vx, vy, vz, m):
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.m = m

    def K_E(self):
        return (0.5*(self.m) * (self.vx**2+self.vy**2+self.vz**2))
    

    def find_distance(self, object2):
        return np.sqrt((self.x-object2.x)**2 + (self.y-object2.y)**2 + (self.z-object2.z)**2)

    def new_position(self, dt):
        self.x += self.x + self.vx*dt
        self.y += self.y + self.vy*dt
        self.z += self.z + self.vz*dt
        return(self.x, self.y, self.z)


class ChargedParticle(particle):
    
    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
    
        super().__init__(mass, x, y, z, vx, vy, vz)
        # Add a new attribute for electric charge
        self.charge = charge
    
    def interaction(self, other):
        separation = self.find_distance(other)
        if separation < 0.25:
            print("interaction")
            
            if self.charge * other.charge < 0:
                self.vx = self.vy =self.vz = 0
                self.charge = other.charge = 0
                print("merge")

            else:
                repel_self = -1 * (self.charge + other.charge) * (self.m / other.m)
                repel_other = -1 * (self.charge + other.charge) * (other.m / self.m)

                self.vx *= repel_self
                self.vy *= repel_self
                self.vz *= repel_self

                other.vx *= repel_other
                other.vy *= repel_other
                other.vz *= repel_other

                print("repel")


#7, testing above (should merge, opposite sign)
print("Test 1")
P1 = ChargedParticle(-5, -5, -5, 1, 1, 1, 1, 0.5)
P2 = ChargedParticle(5, 5, 5, 1, 1, 1, 1, -0.5)

dt = 0.05

for step in range (300):
    P1.new_position(dt)
    P2.new_position(dt)
    P1.interaction(P2)
    print(f"Step {step}:")
    print(f"P1 position = ({P1.x:}, {P1.y:}, {P1.z:}), velocities = ({P1.vx:}, {P1.vy:}, {P1.vz:})")
    print(f"P2 position = ({P2.x:}, {P2.y:}, {P2.z:}), velocities = ({P2.vx:}, {P2.vy:}, {P2.vz:})")
    print()


#8, testing above (should repel, same sign)
print("Test 2")
P1 = ChargedParticle(-5, -5, -5, 2, 2, 2, 1, 0.5)
P2 = ChargedParticle(5, 5, 5, -1, -1, -1, 1, 2.0)

dt = 0.05

for step in range (300):
    P1.new_position(dt)
    P2.new_position(dt)
    P1.interaction(P2)
    print(f"Step {step}:")
    print(f"P1 position = ({P1.x:}, {P1.y:}, {P1.z:}), velocities = ({P1.vx:}, {P1.vy:}, {P1.vz:})")
    print(f"P2 position = ({P2.x:}, {P2.y:}, {P2.z:}), velocities = ({P2.vx:}, {P2.vy:}, {P2.vz:})")
    print()
# Out:
# Test 1
# Step 0:
# P1 position = (-9.95, -9.95, -9.95), velocities = (1, 1, 1)
# P2 position = (10.05, 10.05, 10.05), velocities = (1, 1, 1)
#
# Step 1:
# P1 position = (-19.849999999999998, -19.849999999999998, -19.849999999999998), velocities = (1, 1, 1)
# P2 position = (20.150000000000002, 20.150000000000002, 20.150000000000002), velocities = (1, 1, 1)
#
# Step 2:
# P1 position = (-39.64999999999999, -39.64999999999999, -39.64999999999999), velocities = (1, 1, 1)
# P2 position = (40.35000000000001, 40.35000000000001, 40.35000000000001), velocities = (1, 1, 1)
#
# Step 3:
# P1 position = (-79.24999999999999, -79.24999999999999, -79.24999999999999), velocities = (1, 1, 1)
# P2 position = (80.75000000000001, 80.75000000000001, 80.75000000000001), velocities = (1, 1, 1)
#
# Step 4:
# P1 position = (-158.45, -158.45, -158.45), velocities = (1, 1, 1)
# P2 position = (161.55, 161.55, 161.55), velocities = (1, 1, 1)
#
# Step 5:
# P1 position = (-316.84999999999997, -316.84999999999997, -316.84999999999997), velocities = (1, 1, 1)
# P2 position = (323.15000000000003, 323.15000000000003, 323.15000000000003), velocities = (1, 1, 1)
#
# Step 6:
# P1 position = (-633.6499999999999, -633.6499999999999, -633.6499999999999), velocities = (1, 1, 1)
# P2 position = (646.3500000000001, 646.3500000000001, 646.3500000000001), velocities = (1, 1, 1)
#
# Step 7:
# P1 position = (-1267.2499999999998, -1267.2499999999998, -1267.2499999999998), velocities = (1, 1, 1)
# P2 position = (1292.7500000000002, 1292.7500000000002, 1292.7500000000002), velocities = (1, 1, 1)
#
# Step 8:
# P1 position = (-2534.45, -2534.45, -2534.45), velocities = (1, 1, 1)
# P2 position = (2585.55, 2585.55, 2585.55), velocities = (1, 1, 1)
#
# Step 9:
# P1 position = (-5068.849999999999, -5068.849999999999, -5068.849999999999), velocities = (1, 1, 1)
# P2 position = (5171.150000000001, 5171.150000000001, 5171.150000000001), velocities = (1, 1, 1)
#
# Step 10:
# P1 position = (-10137.649999999998, -10137.649999999998, -10137.649999999998), velocities = (1, 1, 1)
# P2 position = (10342.350000000002, 10342.350000000002, 10342.350000000002), velocities = (1, 1, 1)
#
# Step 11:
# P1 position = (-20275.249999999996, -20275.249999999996, -20275.249999999996), velocities = (1, 1, 1)
# P2 position = (20684.750000000004, 20684.750000000004, 20684.750000000004), velocities = (1, 1, 1)
#
# Step 12:
# P1 position = (-40550.45, -40550.45, -40550.45), velocities = (1, 1, 1)
# P2 position = (41369.55, 41369.55, 41369.55), velocities = (1, 1, 1)
#
# Step 13:
# P1 position = (-81100.84999999999, -81100.84999999999, -81100.84999999999), velocities = (1, 1, 1)
# P2 position = (82739.15000000001, 82739.15000000001, 82739.15000000001), velocities = (1, 1, 1)
#
# Step 14:
# P1 position = (-162201.64999999997, -162201.64999999997, -162201.64999999997), velocities = (1, 1, 1)
# P2 position = (165478.35000000003, 165478.35000000003, 165478.35000000003), velocities = (1, 1, 1)
#
# Step 15:
# P1 position = (-324403.24999999994, -324403.24999999994, -324403.24999999994), velocities = (1, 1, 1)
# P2 position = (330956.75000000006, 330956.75000000006, 330956.75000000006), velocities = (1, 1, 1)
#
# Step 16:
# P1 position = (-648806.45, -648806.45, -648806.45), velocities = (1, 1, 1)
# P2 position = (661913.55, 661913.55, 661913.55), velocities = (1, 1, 1)
#
# Step 17:
# P1 position = (-1297612.8499999999, -1297612.8499999999, -1297612.8499999999), velocities = (1, 1, 1)
# P2 position = (1323827.1500000001, 1323827.1500000001, 1323827.1500000001), velocities = (1, 1, 1)
#
# Step 18:
# P1 position = (-2595225.6499999994, -2595225.6499999994, -2595225.6499999994), velocities = (1, 1, 1)
# P2 position = (2647654.3500000006, 2647654.3500000006, 2647654.3500000006), velocities = (1, 1, 1)
#
# Step 19:
# P1 position = (-5190451.249999999, -5190451.249999999, -5190451.249999999), velocities = (1, 1, 1)
# P2 position = (5295308.750000001, 5295308.750000001, 5295308.750000001), velocities = (1, 1, 1)
#
# Step 20:
# P1 position = (-10380902.45, -10380902.45, -10380902.45), velocities = (1, 1, 1)
# P2 position = (10590617.55, 10590617.55, 10590617.55), velocities = (1, 1, 1)
#
# Step 21:
# P1 position = (-20761804.849999998, -20761804.849999998, -20761804.849999998), velocities = (1, 1, 1)
# P2 position = (21181235.150000002, 21181235.150000002, 21181235.150000002), velocities = (1, 1, 1)
#
# Step 22:
# P1 position = (-41523609.64999999, -41523609.64999999, -41523609.64999999), velocities = (1, 1, 1)
# P2 position = (42362470.35000001, 42362470.35000001, 42362470.35000001), velocities = (1, 1, 1)
#
# Step 23:
# P1 position = (-83047219.24999999, -83047219.24999999, -83047219.24999999), velocities = (1, 1, 1)
# P2 position = (84724940.75000001, 84724940.75000001, 84724940.75000001), velocities = (1, 1, 1)
#
# Step 24:
# P1 position = (-166094438.45, -166094438.45, -166094438.45), velocities = (1, 1, 1)
# P2 position = (169449881.55, 169449881.55, 169449881.55), velocities = (1, 1, 1)
#
# Step 25:
# P1 position = (-332188876.84999996, -332188876.84999996, -332188876.84999996), velocities = (1, 1, 1)
# P2 position = (338899763.15000004, 338899763.15000004, 338899763.15000004), velocities = (1, 1, 1)
#
# Step 26:
# P1 position = (-664377753.6499999, -664377753.6499999, -664377753.6499999), velocities = (1, 1, 1)
# P2 position = (677799526.3500001, 677799526.3500001, 677799526.3500001), velocities = (1, 1, 1)
#
# Step 27:
# P1 position = (-1328755507.2499998, -1328755507.2499998, -1328755507.2499998), velocities = (1, 1, 1)
# P2 position = (1355599052.7500002, 1355599052.7500002, 1355599052.7500002), velocities = (1, 1, 1)
#
# Step 28:
# P1 position = (-2657511014.45, -2657511014.45, -2657511014.45), velocities = (1, 1, 1)
# P2 position = (2711198105.55, 2711198105.55, 2711198105.55), velocities = (1, 1, 1)
#
# Step 29:
# P1 position = (-5315022028.849999, -5315022028.849999, -5315022028.849999), velocities = (1, 1, 1)
# P2 position = (5422396211.150001, 5422396211.150001, 5422396211.150001), velocities = (1, 1, 1)
#
# Step 30:
# P1 position = (-10630044057.649998, -10630044057.649998, -10630044057.649998), velocities = (1, 1, 1)
# P2 position = (10844792422.350002, 10844792422.350002, 10844792422.350002), velocities = (1, 1, 1)
#
# Step 31:
# P1 position = (-21260088115.249996, -21260088115.249996, -21260088115.249996), velocities = (1, 1, 1)
# P2 position = (21689584844.750004, 21689584844.750004, 21689584844.750004), velocities = (1, 1, 1)
#
# Step 32:
# P1 position = (-42520176230.45, -42520176230.45, -42520176230.45), velocities = (1, 1, 1)
# P2 position = (43379169689.55, 43379169689.55, 43379169689.55), velocities = (1, 1, 1)
#
# Step 33:
# P1 position = (-85040352460.84999, -85040352460.84999, -85040352460.84999), velocities = (1, 1, 1)
# P2 position = (86758339379.15001, 86758339379.15001, 86758339379.15001), velocities = (1, 1, 1)
#
# Step 34:
# P1 position = (-170080704921.64996, -170080704921.64996, -170080704921.64996), velocities = (1, 1, 1)
# P2 position = (173516678758.35004, 173516678758.35004, 173516678758.35004), velocities = (1, 1, 1)
#
# Step 35:
# P1 position = (-340161409843.24994, -340161409843.24994, -340161409843.24994), velocities = (1, 1, 1)
# P2 position = (347033357516.75006, 347033357516.75006, 347033357516.75006), velocities = (1, 1, 1)
#
# Step 36:
# P1 position = (-680322819686.45, -680322819686.45, -680322819686.45), velocities = (1, 1, 1)
# P2 position = (694066715033.55, 694066715033.55, 694066715033.55), velocities = (1, 1, 1)
#
# Step 37:
# P1 position = (-1360645639372.8499, -1360645639372.8499, -1360645639372.8499), velocities = (1, 1, 1)
# P2 position = (1388133430067.1501, 1388133430067.1501, 1388133430067.1501), velocities = (1, 1, 1)
#
# Step 38:
# P1 position = (-2721291278745.6494, -2721291278745.6494, -2721291278745.6494), velocities = (1, 1, 1)
# P2 position = (2776266860134.3506, 2776266860134.3506, 2776266860134.3506), velocities = (1, 1, 1)
#
# Step 39:
# P1 position = (-5442582557491.249, -5442582557491.249, -5442582557491.249), velocities = (1, 1, 1)
# P2 position = (5552533720268.751, 5552533720268.751, 5552533720268.751), velocities = (1, 1, 1)
#
# Step 40:
# P1 position = (-10885165114982.45, -10885165114982.45, -10885165114982.45), velocities = (1, 1, 1)
# P2 position = (11105067440537.55, 11105067440537.55, 11105067440537.55), velocities = (1, 1, 1)
#
# Step 41:
# P1 position = (-21770330229964.848, -21770330229964.848, -21770330229964.848), velocities = (1, 1, 1)
# P2 position = (22210134881075.152, 22210134881075.152, 22210134881075.152), velocities = (1, 1, 1)
#
# Step 42:
# P1 position = (-43540660459929.64, -43540660459929.64, -43540660459929.64), velocities = (1, 1, 1)
# P2 position = (44420269762150.36, 44420269762150.36, 44420269762150.36), velocities = (1, 1, 1)
#
# Step 43:
# P1 position = (-87081320919859.23, -87081320919859.23, -87081320919859.23), velocities = (1, 1, 1)
# P2 position = (88840539524300.77, 88840539524300.77, 88840539524300.77), velocities = (1, 1, 1)
#
# Step 44:
# P1 position = (-174162641839718.44, -174162641839718.44, -174162641839718.44), velocities = (1, 1, 1)
# P2 position = (177681079048601.56, 177681079048601.56, 177681079048601.56), velocities = (1, 1, 1)
#
# Step 45:
# P1 position = (-348325283679436.8, -348325283679436.8, -348325283679436.8), velocities = (1, 1, 1)
# P2 position = (355362158097203.2, 355362158097203.2, 355362158097203.2), velocities = (1, 1, 1)
#
# Step 46:
# P1 position = (-696650567358873.5, -696650567358873.5, -696650567358873.5), velocities = (1, 1, 1)
# P2 position = (710724316194406.5, 710724316194406.5, 710724316194406.5), velocities = (1, 1, 1)
#
# Step 47:
# P1 position = (-1393301134717747.0, -1393301134717747.0, -1393301134717747.0), velocities = (1, 1, 1)
# P2 position = (1421448632388813.0, 1421448632388813.0, 1421448632388813.0), velocities = (1, 1, 1)
#
# Step 48:
# P1 position = (-2786602269435494.0, -2786602269435494.0, -2786602269435494.0), velocities = (1, 1, 1)
# P2 position = (2842897264777626.0, 2842897264777626.0, 2842897264777626.0), velocities = (1, 1, 1)
#
# Step 49:
# P1 position = (-5573204538870988.0, -5573204538870988.0, -5573204538870988.0), velocities = (1, 1, 1)
# P2 position = (5685794529555252.0, 5685794529555252.0, 5685794529555252.0), velocities = (1, 1, 1)
#
# Step 50:
# P1 position = (-1.1146409077741976e+16, -1.1146409077741976e+16, -1.1146409077741976e+16), velocities = (1, 1, 1)
# P2 position = (1.1371589059110504e+16, 1.1371589059110504e+16, 1.1371589059110504e+16), velocities = (1, 1, 1)
#
# Step 51:
# P1 position = (-2.229281815548395e+16, -2.229281815548395e+16, -2.229281815548395e+16), velocities = (1, 1, 1)
# P2 position = (2.274317811822101e+16, 2.274317811822101e+16, 2.274317811822101e+16), velocities = (1, 1, 1)
#
# Step 52:
# P1 position = (-4.45856363109679e+16, -4.45856363109679e+16, -4.45856363109679e+16), velocities = (1, 1, 1)
# P2 position = (4.548635623644202e+16, 4.548635623644202e+16, 4.548635623644202e+16), velocities = (1, 1, 1)
#
# Step 53:
# P1 position = (-8.91712726219358e+16, -8.91712726219358e+16, -8.91712726219358e+16), velocities = (1, 1, 1)
# P2 position = (9.097271247288403e+16, 9.097271247288403e+16, 9.097271247288403e+16), velocities = (1, 1, 1)
#
# Step 54:
# P1 position = (-1.783425452438716e+17, -1.783425452438716e+17, -1.783425452438716e+17), velocities = (1, 1, 1)
# P2 position = (1.8194542494576806e+17, 1.8194542494576806e+17, 1.8194542494576806e+17), velocities = (1, 1, 1)
#
# Step 55:
# P1 position = (-3.566850904877432e+17, -3.566850904877432e+17, -3.566850904877432e+17), velocities = (1, 1, 1)
# P2 position = (3.638908498915361e+17, 3.638908498915361e+17, 3.638908498915361e+17), velocities = (1, 1, 1)
#
# Step 56:
# P1 position = (-7.133701809754865e+17, -7.133701809754865e+17, -7.133701809754865e+17), velocities = (1, 1, 1)
# P2 position = (7.277816997830723e+17, 7.277816997830723e+17, 7.277816997830723e+17), velocities = (1, 1, 1)
#
# Step 57:
# P1 position = (-1.426740361950973e+18, -1.426740361950973e+18, -1.426740361950973e+18), velocities = (1, 1, 1)
# P2 position = (1.4555633995661445e+18, 1.4555633995661445e+18, 1.4555633995661445e+18), velocities = (1, 1, 1)
#
# Step 58:
# P1 position = (-2.853480723901946e+18, -2.853480723901946e+18, -2.853480723901946e+18), velocities = (1, 1, 1)
# P2 position = (2.911126799132289e+18, 2.911126799132289e+18, 2.911126799132289e+18), velocities = (1, 1, 1)
#
# Step 59:
# P1 position = (-5.706961447803892e+18, -5.706961447803892e+18, -5.706961447803892e+18), velocities = (1, 1, 1)
# P2 position = (5.822253598264578e+18, 5.822253598264578e+18, 5.822253598264578e+18), velocities = (1, 1, 1)
#
# Step 60:
# P1 position = (-1.1413922895607783e+19, -1.1413922895607783e+19, -1.1413922895607783e+19), velocities = (1, 1, 1)
# P2 position = (1.1644507196529156e+19, 1.1644507196529156e+19, 1.1644507196529156e+19), velocities = (1, 1, 1)
#
# Step 61:
# P1 position = (-2.2827845791215567e+19, -2.2827845791215567e+19, -2.2827845791215567e+19), velocities = (1, 1, 1)
# P2 position = (2.3289014393058312e+19, 2.3289014393058312e+19, 2.3289014393058312e+19), velocities = (1, 1, 1)
#
# Step 62:
# P1 position = (-4.565569158243113e+19, -4.565569158243113e+19, -4.565569158243113e+19), velocities = (1, 1, 1)
# P2 position = (4.6578028786116624e+19, 4.6578028786116624e+19, 4.6578028786116624e+19), velocities = (1, 1, 1)
#
# Step 63:
# P1 position = (-9.131138316486227e+19, -9.131138316486227e+19, -9.131138316486227e+19), velocities = (1, 1, 1)
# P2 position = (9.315605757223325e+19, 9.315605757223325e+19, 9.315605757223325e+19), velocities = (1, 1, 1)
#
# Step 64:
# P1 position = (-1.8262276632972453e+20, -1.8262276632972453e+20, -1.8262276632972453e+20), velocities = (1, 1, 1)
# P2 position = (1.863121151444665e+20, 1.863121151444665e+20, 1.863121151444665e+20), velocities = (1, 1, 1)
#
# Step 65:
# P1 position = (-3.652455326594491e+20, -3.652455326594491e+20, -3.652455326594491e+20), velocities = (1, 1, 1)
# P2 position = (3.72624230288933e+20, 3.72624230288933e+20, 3.72624230288933e+20), velocities = (1, 1, 1)
#
# Step 66:
# P1 position = (-7.304910653188981e+20, -7.304910653188981e+20, -7.304910653188981e+20), velocities = (1, 1, 1)
# P2 position = (7.45248460577866e+20, 7.45248460577866e+20, 7.45248460577866e+20), velocities = (1, 1, 1)
#
# Step 67:
# P1 position = (-1.4609821306377963e+21, -1.4609821306377963e+21, -1.4609821306377963e+21), velocities = (1, 1, 1)
# P2 position = (1.490496921155732e+21, 1.490496921155732e+21, 1.490496921155732e+21), velocities = (1, 1, 1)
#
# Step 68:
# P1 position = (-2.9219642612755926e+21, -2.9219642612755926e+21, -2.9219642612755926e+21), velocities = (1, 1, 1)
# P2 position = (2.980993842311464e+21, 2.980993842311464e+21, 2.980993842311464e+21), velocities = (1, 1, 1)
#
# Step 69:
# P1 position = (-5.843928522551185e+21, -5.843928522551185e+21, -5.843928522551185e+21), velocities = (1, 1, 1)
# P2 position = (5.961987684622928e+21, 5.961987684622928e+21, 5.961987684622928e+21), velocities = (1, 1, 1)
#
# Step 70:
# P1 position = (-1.168785704510237e+22, -1.168785704510237e+22, -1.168785704510237e+22), velocities = (1, 1, 1)
# P2 position = (1.1923975369245856e+22, 1.1923975369245856e+22, 1.1923975369245856e+22), velocities = (1, 1, 1)
#
# Step 71:
# P1 position = (-2.337571409020474e+22, -2.337571409020474e+22, -2.337571409020474e+22), velocities = (1, 1, 1)
# P2 position = (2.384795073849171e+22, 2.384795073849171e+22, 2.384795073849171e+22), velocities = (1, 1, 1)
#
# Step 72:
# P1 position = (-4.675142818040948e+22, -4.675142818040948e+22, -4.675142818040948e+22), velocities = (1, 1, 1)
# P2 position = (4.769590147698342e+22, 4.769590147698342e+22, 4.769590147698342e+22), velocities = (1, 1, 1)
#
# Step 73:
# P1 position = (-9.350285636081896e+22, -9.350285636081896e+22, -9.350285636081896e+22), velocities = (1, 1, 1)
# P2 position = (9.539180295396685e+22, 9.539180295396685e+22, 9.539180295396685e+22), velocities = (1, 1, 1)
#
# Step 74:
# P1 position = (-1.8700571272163792e+23, -1.8700571272163792e+23, -1.8700571272163792e+23), velocities = (1, 1, 1)
# P2 position = (1.907836059079337e+23, 1.907836059079337e+23, 1.907836059079337e+23), velocities = (1, 1, 1)
#
# Step 75:
# P1 position = (-3.7401142544327585e+23, -3.7401142544327585e+23, -3.7401142544327585e+23), velocities = (1, 1, 1)
# P2 position = (3.815672118158674e+23, 3.815672118158674e+23, 3.815672118158674e+23), velocities = (1, 1, 1)
#
# Step 76:
# P1 position = (-7.480228508865517e+23, -7.480228508865517e+23, -7.480228508865517e+23), velocities = (1, 1, 1)
# P2 position = (7.631344236317348e+23, 7.631344236317348e+23, 7.631344236317348e+23), velocities = (1, 1, 1)
#
# Step 77:
# P1 position = (-1.4960457017731034e+24, -1.4960457017731034e+24, -1.4960457017731034e+24), velocities = (1, 1, 1)
# P2 position = (1.5262688472634695e+24, 1.5262688472634695e+24, 1.5262688472634695e+24), velocities = (1, 1, 1)
#
# Step 78:
# P1 position = (-2.992091403546207e+24, -2.992091403546207e+24, -2.992091403546207e+24), velocities = (1, 1, 1)
# P2 position = (3.052537694526939e+24, 3.052537694526939e+24, 3.052537694526939e+24), velocities = (1, 1, 1)
#
# Step 79:
# P1 position = (-5.984182807092414e+24, -5.984182807092414e+24, -5.984182807092414e+24), velocities = (1, 1, 1)
# P2 position = (6.105075389053878e+24, 6.105075389053878e+24, 6.105075389053878e+24), velocities = (1, 1, 1)
#
# Step 80:
# P1 position = (-1.1968365614184827e+25, -1.1968365614184827e+25, -1.1968365614184827e+25), velocities = (1, 1, 1)
# P2 position = (1.2210150778107756e+25, 1.2210150778107756e+25, 1.2210150778107756e+25), velocities = (1, 1, 1)
#
# Step 81:
# P1 position = (-2.3936731228369654e+25, -2.3936731228369654e+25, -2.3936731228369654e+25), velocities = (1, 1, 1)
# P2 position = (2.4420301556215513e+25, 2.4420301556215513e+25, 2.4420301556215513e+25), velocities = (1, 1, 1)
#
# Step 82:
# P1 position = (-4.787346245673931e+25, -4.787346245673931e+25, -4.787346245673931e+25), velocities = (1, 1, 1)
# P2 position = (4.8840603112431026e+25, 4.8840603112431026e+25, 4.8840603112431026e+25), velocities = (1, 1, 1)
#
# Step 83:
# P1 position = (-9.574692491347862e+25, -9.574692491347862e+25, -9.574692491347862e+25), velocities = (1, 1, 1)
# P2 position = (9.768120622486205e+25, 9.768120622486205e+25, 9.768120622486205e+25), velocities = (1, 1, 1)
#
# Step 84:
# P1 position = (-1.9149384982695723e+26, -1.9149384982695723e+26, -1.9149384982695723e+26), velocities = (1, 1, 1)
# P2 position = (1.953624124497241e+26, 1.953624124497241e+26, 1.953624124497241e+26), velocities = (1, 1, 1)
#
# Step 85:
# P1 position = (-3.829876996539145e+26, -3.829876996539145e+26, -3.829876996539145e+26), velocities = (1, 1, 1)
# P2 position = (3.907248248994482e+26, 3.907248248994482e+26, 3.907248248994482e+26), velocities = (1, 1, 1)
#
# Step 86:
# P1 position = (-7.65975399307829e+26, -7.65975399307829e+26, -7.65975399307829e+26), velocities = (1, 1, 1)
# P2 position = (7.814496497988964e+26, 7.814496497988964e+26, 7.814496497988964e+26), velocities = (1, 1, 1)
#
# Step 87:
# P1 position = (-1.531950798615658e+27, -1.531950798615658e+27, -1.531950798615658e+27), velocities = (1, 1, 1)
# P2 position = (1.5628992995977928e+27, 1.5628992995977928e+27, 1.5628992995977928e+27), velocities = (1, 1, 1)
#
# Step 88:
# P1 position = (-3.063901597231316e+27, -3.063901597231316e+27, -3.063901597231316e+27), velocities = (1, 1, 1)
# P2 position = (3.1257985991955856e+27, 3.1257985991955856e+27, 3.1257985991955856e+27), velocities = (1, 1, 1)
#
# Step 89:
# P1 position = (-6.127803194462631e+27, -6.127803194462631e+27, -6.127803194462631e+27), velocities = (1, 1, 1)
# P2 position = (6.251597198391171e+27, 6.251597198391171e+27, 6.251597198391171e+27), velocities = (1, 1, 1)
#
# Step 90:
# P1 position = (-1.2255606388925263e+28, -1.2255606388925263e+28, -1.2255606388925263e+28), velocities = (1, 1, 1)
# P2 position = (1.2503194396782343e+28, 1.2503194396782343e+28, 1.2503194396782343e+28), velocities = (1, 1, 1)
#
# Step 91:
# P1 position = (-2.4511212777850526e+28, -2.4511212777850526e+28, -2.4511212777850526e+28), velocities = (1, 1, 1)
# P2 position = (2.5006388793564685e+28, 2.5006388793564685e+28, 2.5006388793564685e+28), velocities = (1, 1, 1)
#
# Step 92:
# P1 position = (-4.902242555570105e+28, -4.902242555570105e+28, -4.902242555570105e+28), velocities = (1, 1, 1)
# P2 position = (5.001277758712937e+28, 5.001277758712937e+28, 5.001277758712937e+28), velocities = (1, 1, 1)
#
# Step 93:
# P1 position = (-9.80448511114021e+28, -9.80448511114021e+28, -9.80448511114021e+28), velocities = (1, 1, 1)
# P2 position = (1.0002555517425874e+29, 1.0002555517425874e+29, 1.0002555517425874e+29), velocities = (1, 1, 1)
#
# Step 94:
# P1 position = (-1.960897022228042e+29, -1.960897022228042e+29, -1.960897022228042e+29), velocities = (1, 1, 1)
# P2 position = (2.0005111034851748e+29, 2.0005111034851748e+29, 2.0005111034851748e+29), velocities = (1, 1, 1)
#
# Step 95:
# P1 position = (-3.921794044456084e+29, -3.921794044456084e+29, -3.921794044456084e+29), velocities = (1, 1, 1)
# P2 position = (4.0010222069703496e+29, 4.0010222069703496e+29, 4.0010222069703496e+29), velocities = (1, 1, 1)
#
# Step 96:
# P1 position = (-7.843588088912168e+29, -7.843588088912168e+29, -7.843588088912168e+29), velocities = (1, 1, 1)
# P2 position = (8.002044413940699e+29, 8.002044413940699e+29, 8.002044413940699e+29), velocities = (1, 1, 1)
#
# Step 97:
# P1 position = (-1.5687176177824337e+30, -1.5687176177824337e+30, -1.5687176177824337e+30), velocities = (1, 1, 1)
# P2 position = (1.6004088827881398e+30, 1.6004088827881398e+30, 1.6004088827881398e+30), velocities = (1, 1, 1)
#
# Step 98:
# P1 position = (-3.1374352355648673e+30, -3.1374352355648673e+30, -3.1374352355648673e+30), velocities = (1, 1, 1)
# P2 position = (3.2008177655762797e+30, 3.2008177655762797e+30, 3.2008177655762797e+30), velocities = (1, 1, 1)
#
# Step 99:
# P1 position = (-6.274870471129735e+30, -6.274870471129735e+30, -6.274870471129735e+30), velocities = (1, 1, 1)
# P2 position = (6.401635531152559e+30, 6.401635531152559e+30, 6.401635531152559e+30), velocities = (1, 1, 1)
#
# Step 100:
# P1 position = (-1.254974094225947e+31, -1.254974094225947e+31, -1.254974094225947e+31), velocities = (1, 1, 1)
# P2 position = (1.2803271062305119e+31, 1.2803271062305119e+31, 1.2803271062305119e+31), velocities = (1, 1, 1)
#
# Step 101:
# P1 position = (-2.509948188451894e+31, -2.509948188451894e+31, -2.509948188451894e+31), velocities = (1, 1, 1)
# P2 position = (2.5606542124610238e+31, 2.5606542124610238e+31, 2.5606542124610238e+31), velocities = (1, 1, 1)
#
# Step 102:
# P1 position = (-5.019896376903788e+31, -5.019896376903788e+31, -5.019896376903788e+31), velocities = (1, 1, 1)
# P2 position = (5.1213084249220475e+31, 5.1213084249220475e+31, 5.1213084249220475e+31), velocities = (1, 1, 1)
#
# Step 103:
# P1 position = (-1.0039792753807575e+32, -1.0039792753807575e+32, -1.0039792753807575e+32), velocities = (1, 1, 1)
# P2 position = (1.0242616849844095e+32, 1.0242616849844095e+32, 1.0242616849844095e+32), velocities = (1, 1, 1)
#
# Step 104:
# P1 position = (-2.007958550761515e+32, -2.007958550761515e+32, -2.007958550761515e+32), velocities = (1, 1, 1)
# P2 position = (2.048523369968819e+32, 2.048523369968819e+32, 2.048523369968819e+32), velocities = (1, 1, 1)
#
# Step 105:
# P1 position = (-4.01591710152303e+32, -4.01591710152303e+32, -4.01591710152303e+32), velocities = (1, 1, 1)
# P2 position = (4.097046739937638e+32, 4.097046739937638e+32, 4.097046739937638e+32), velocities = (1, 1, 1)
#
# Step 106:
# P1 position = (-8.03183420304606e+32, -8.03183420304606e+32, -8.03183420304606e+32), velocities = (1, 1, 1)
# P2 position = (8.194093479875276e+32, 8.194093479875276e+32, 8.194093479875276e+32), velocities = (1, 1, 1)
#
# Step 107:
# P1 position = (-1.606366840609212e+33, -1.606366840609212e+33, -1.606366840609212e+33), velocities = (1, 1, 1)
# P2 position = (1.6388186959750552e+33, 1.6388186959750552e+33, 1.6388186959750552e+33), velocities = (1, 1, 1)
#
# Step 108:
# P1 position = (-3.212733681218424e+33, -3.212733681218424e+33, -3.212733681218424e+33), velocities = (1, 1, 1)
# P2 position = (3.2776373919501104e+33, 3.2776373919501104e+33, 3.2776373919501104e+33), velocities = (1, 1, 1)
#
# Step 109:
# P1 position = (-6.425467362436848e+33, -6.425467362436848e+33, -6.425467362436848e+33), velocities = (1, 1, 1)
# P2 position = (6.555274783900221e+33, 6.555274783900221e+33, 6.555274783900221e+33), velocities = (1, 1, 1)
#
# Step 110:
# P1 position = (-1.2850934724873697e+34, -1.2850934724873697e+34, -1.2850934724873697e+34), velocities = (1, 1, 1)
# P2 position = (1.3110549567800442e+34, 1.3110549567800442e+34, 1.3110549567800442e+34), velocities = (1, 1, 1)
#
# Step 111:
# P1 position = (-2.5701869449747393e+34, -2.5701869449747393e+34, -2.5701869449747393e+34), velocities = (1, 1, 1)
# P2 position = (2.6221099135600883e+34, 2.6221099135600883e+34, 2.6221099135600883e+34), velocities = (1, 1, 1)
#
# Step 112:
# P1 position = (-5.140373889949479e+34, -5.140373889949479e+34, -5.140373889949479e+34), velocities = (1, 1, 1)
# P2 position = (5.244219827120177e+34, 5.244219827120177e+34, 5.244219827120177e+34), velocities = (1, 1, 1)
#
# Step 113:
# P1 position = (-1.0280747779898957e+35, -1.0280747779898957e+35, -1.0280747779898957e+35), velocities = (1, 1, 1)
# P2 position = (1.0488439654240353e+35, 1.0488439654240353e+35, 1.0488439654240353e+35), velocities = (1, 1, 1)
#
# Step 114:
# P1 position = (-2.0561495559797914e+35, -2.0561495559797914e+35, -2.0561495559797914e+35), velocities = (1, 1, 1)
# P2 position = (2.0976879308480707e+35, 2.0976879308480707e+35, 2.0976879308480707e+35), velocities = (1, 1, 1)
#
# Step 115:
# P1 position = (-4.112299111959583e+35, -4.112299111959583e+35, -4.112299111959583e+35), velocities = (1, 1, 1)
# P2 position = (4.195375861696141e+35, 4.195375861696141e+35, 4.195375861696141e+35), velocities = (1, 1, 1)
#
# Step 116:
# P1 position = (-8.224598223919166e+35, -8.224598223919166e+35, -8.224598223919166e+35), velocities = (1, 1, 1)
# P2 position = (8.390751723392283e+35, 8.390751723392283e+35, 8.390751723392283e+35), velocities = (1, 1, 1)
#
# Step 117:
# P1 position = (-1.6449196447838332e+36, -1.6449196447838332e+36, -1.6449196447838332e+36), velocities = (1, 1, 1)
# P2 position = (1.6781503446784565e+36, 1.6781503446784565e+36, 1.6781503446784565e+36), velocities = (1, 1, 1)
#
# Step 118:
# P1 position = (-3.2898392895676663e+36, -3.2898392895676663e+36, -3.2898392895676663e+36), velocities = (1, 1, 1)
# P2 position = (3.356300689356913e+36, 3.356300689356913e+36, 3.356300689356913e+36), velocities = (1, 1, 1)
#
# Step 119:
# P1 position = (-6.579678579135333e+36, -6.579678579135333e+36, -6.579678579135333e+36), velocities = (1, 1, 1)
# P2 position = (6.712601378713826e+36, 6.712601378713826e+36, 6.712601378713826e+36), velocities = (1, 1, 1)
#
# Step 120:
# P1 position = (-1.3159357158270665e+37, -1.3159357158270665e+37, -1.3159357158270665e+37), velocities = (1, 1, 1)
# P2 position = (1.3425202757427652e+37, 1.3425202757427652e+37, 1.3425202757427652e+37), velocities = (1, 1, 1)
#
# Step 121:
# P1 position = (-2.631871431654133e+37, -2.631871431654133e+37, -2.631871431654133e+37), velocities = (1, 1, 1)
# P2 position = (2.6850405514855304e+37, 2.6850405514855304e+37, 2.6850405514855304e+37), velocities = (1, 1, 1)
#
# Step 122:
# P1 position = (-5.263742863308266e+37, -5.263742863308266e+37, -5.263742863308266e+37), velocities = (1, 1, 1)
# P2 position = (5.370081102971061e+37, 5.370081102971061e+37, 5.370081102971061e+37), velocities = (1, 1, 1)
#
# Step 123:
# P1 position = (-1.0527485726616532e+38, -1.0527485726616532e+38, -1.0527485726616532e+38), velocities = (1, 1, 1)
# P2 position = (1.0740162205942122e+38, 1.0740162205942122e+38, 1.0740162205942122e+38), velocities = (1, 1, 1)
#
# Step 124:
# P1 position = (-2.1054971453233064e+38, -2.1054971453233064e+38, -2.1054971453233064e+38), velocities = (1, 1, 1)
# P2 position = (2.1480324411884244e+38, 2.1480324411884244e+38, 2.1480324411884244e+38), velocities = (1, 1, 1)
#
# Step 125:
# P1 position = (-4.210994290646613e+38, -4.210994290646613e+38, -4.210994290646613e+38), velocities = (1, 1, 1)
# P2 position = (4.296064882376849e+38, 4.296064882376849e+38, 4.296064882376849e+38), velocities = (1, 1, 1)
#
# Step 126:
# P1 position = (-8.421988581293226e+38, -8.421988581293226e+38, -8.421988581293226e+38), velocities = (1, 1, 1)
# P2 position = (8.592129764753697e+38, 8.592129764753697e+38, 8.592129764753697e+38), velocities = (1, 1, 1)
#
# Step 127:
# P1 position = (-1.6843977162586452e+39, -1.6843977162586452e+39, -1.6843977162586452e+39), velocities = (1, 1, 1)
# P2 position = (1.7184259529507395e+39, 1.7184259529507395e+39, 1.7184259529507395e+39), velocities = (1, 1, 1)
#
# Step 128:
# P1 position = (-3.3687954325172903e+39, -3.3687954325172903e+39, -3.3687954325172903e+39), velocities = (1, 1, 1)
# P2 position = (3.436851905901479e+39, 3.436851905901479e+39, 3.436851905901479e+39), velocities = (1, 1, 1)
#
# Step 129:
# P1 position = (-6.737590865034581e+39, -6.737590865034581e+39, -6.737590865034581e+39), velocities = (1, 1, 1)
# P2 position = (6.873703811802958e+39, 6.873703811802958e+39, 6.873703811802958e+39), velocities = (1, 1, 1)
#
# Step 130:
# P1 position = (-1.3475181730069161e+40, -1.3475181730069161e+40, -1.3475181730069161e+40), velocities = (1, 1, 1)
# P2 position = (1.3747407623605916e+40, 1.3747407623605916e+40, 1.3747407623605916e+40), velocities = (1, 1, 1)
#
# Step 131:
# P1 position = (-2.6950363460138322e+40, -2.6950363460138322e+40, -2.6950363460138322e+40), velocities = (1, 1, 1)
# P2 position = (2.749481524721183e+40, 2.749481524721183e+40, 2.749481524721183e+40), velocities = (1, 1, 1)
#
# Step 132:
# P1 position = (-5.3900726920276645e+40, -5.3900726920276645e+40, -5.3900726920276645e+40), velocities = (1, 1, 1)
# P2 position = (5.498963049442366e+40, 5.498963049442366e+40, 5.498963049442366e+40), velocities = (1, 1, 1)
#
# Step 133:
# P1 position = (-1.0780145384055329e+41, -1.0780145384055329e+41, -1.0780145384055329e+41), velocities = (1, 1, 1)
# P2 position = (1.0997926098884733e+41, 1.0997926098884733e+41, 1.0997926098884733e+41), velocities = (1, 1, 1)
#
# Step 134:
# P1 position = (-2.1560290768110658e+41, -2.1560290768110658e+41, -2.1560290768110658e+41), velocities = (1, 1, 1)
# P2 position = (2.1995852197769465e+41, 2.1995852197769465e+41, 2.1995852197769465e+41), velocities = (1, 1, 1)
#
# Step 135:
# P1 position = (-4.3120581536221316e+41, -4.3120581536221316e+41, -4.3120581536221316e+41), velocities = (1, 1, 1)
# P2 position = (4.399170439553893e+41, 4.399170439553893e+41, 4.399170439553893e+41), velocities = (1, 1, 1)
#
# Step 136:
# P1 position = (-8.624116307244263e+41, -8.624116307244263e+41, -8.624116307244263e+41), velocities = (1, 1, 1)
# P2 position = (8.798340879107786e+41, 8.798340879107786e+41, 8.798340879107786e+41), velocities = (1, 1, 1)
#
# Step 137:
# P1 position = (-1.7248232614488526e+42, -1.7248232614488526e+42, -1.7248232614488526e+42), velocities = (1, 1, 1)
# P2 position = (1.7596681758215572e+42, 1.7596681758215572e+42, 1.7596681758215572e+42), velocities = (1, 1, 1)
#
# Step 138:
# P1 position = (-3.449646522897705e+42, -3.449646522897705e+42, -3.449646522897705e+42), velocities = (1, 1, 1)
# P2 position = (3.5193363516431145e+42, 3.5193363516431145e+42, 3.5193363516431145e+42), velocities = (1, 1, 1)
#
# Step 139:
# P1 position = (-6.89929304579541e+42, -6.89929304579541e+42, -6.89929304579541e+42), velocities = (1, 1, 1)
# P2 position = (7.038672703286229e+42, 7.038672703286229e+42, 7.038672703286229e+42), velocities = (1, 1, 1)
#
# Step 140:
# P1 position = (-1.379858609159082e+43, -1.379858609159082e+43, -1.379858609159082e+43), velocities = (1, 1, 1)
# P2 position = (1.4077345406572458e+43, 1.4077345406572458e+43, 1.4077345406572458e+43), velocities = (1, 1, 1)
#
# Step 141:
# P1 position = (-2.759717218318164e+43, -2.759717218318164e+43, -2.759717218318164e+43), velocities = (1, 1, 1)
# P2 position = (2.8154690813144916e+43, 2.8154690813144916e+43, 2.8154690813144916e+43), velocities = (1, 1, 1)
#
# Step 142:
# P1 position = (-5.519434436636328e+43, -5.519434436636328e+43, -5.519434436636328e+43), velocities = (1, 1, 1)
# P2 position = (5.630938162628983e+43, 5.630938162628983e+43, 5.630938162628983e+43), velocities = (1, 1, 1)
#
# Step 143:
# P1 position = (-1.1038868873272657e+44, -1.1038868873272657e+44, -1.1038868873272657e+44), velocities = (1, 1, 1)
# P2 position = (1.1261876325257966e+44, 1.1261876325257966e+44, 1.1261876325257966e+44), velocities = (1, 1, 1)
#
# Step 144:
# P1 position = (-2.2077737746545314e+44, -2.2077737746545314e+44, -2.2077737746545314e+44), velocities = (1, 1, 1)
# P2 position = (2.2523752650515933e+44, 2.2523752650515933e+44, 2.2523752650515933e+44), velocities = (1, 1, 1)
#
# Step 145:
# P1 position = (-4.415547549309063e+44, -4.415547549309063e+44, -4.415547549309063e+44), velocities = (1, 1, 1)
# P2 position = (4.5047505301031865e+44, 4.5047505301031865e+44, 4.5047505301031865e+44), velocities = (1, 1, 1)
#
# Step 146:
# P1 position = (-8.831095098618125e+44, -8.831095098618125e+44, -8.831095098618125e+44), velocities = (1, 1, 1)
# P2 position = (9.009501060206373e+44, 9.009501060206373e+44, 9.009501060206373e+44), velocities = (1, 1, 1)
#
# Step 147:
# P1 position = (-1.766219019723625e+45, -1.766219019723625e+45, -1.766219019723625e+45), velocities = (1, 1, 1)
# P2 position = (1.8019002120412746e+45, 1.8019002120412746e+45, 1.8019002120412746e+45), velocities = (1, 1, 1)
#
# Step 148:
# P1 position = (-3.53243803944725e+45, -3.53243803944725e+45, -3.53243803944725e+45), velocities = (1, 1, 1)
# P2 position = (3.603800424082549e+45, 3.603800424082549e+45, 3.603800424082549e+45), velocities = (1, 1, 1)
#
# Step 149:
# P1 position = (-7.0648760788945e+45, -7.0648760788945e+45, -7.0648760788945e+45), velocities = (1, 1, 1)
# P2 position = (7.207600848165098e+45, 7.207600848165098e+45, 7.207600848165098e+45), velocities = (1, 1, 1)
#
# Step 150:
# P1 position = (-1.4129752157789e+46, -1.4129752157789e+46, -1.4129752157789e+46), velocities = (1, 1, 1)
# P2 position = (1.4415201696330197e+46, 1.4415201696330197e+46, 1.4415201696330197e+46), velocities = (1, 1, 1)
#
# Step 151:
# P1 position = (-2.8259504315578e+46, -2.8259504315578e+46, -2.8259504315578e+46), velocities = (1, 1, 1)
# P2 position = (2.8830403392660394e+46, 2.8830403392660394e+46, 2.8830403392660394e+46), velocities = (1, 1, 1)
#
# Step 152:
# P1 position = (-5.6519008631156e+46, -5.6519008631156e+46, -5.6519008631156e+46), velocities = (1, 1, 1)
# P2 position = (5.766080678532079e+46, 5.766080678532079e+46, 5.766080678532079e+46), velocities = (1, 1, 1)
#
# Step 153:
# P1 position = (-1.13038017262312e+47, -1.13038017262312e+47, -1.13038017262312e+47), velocities = (1, 1, 1)
# P2 position = (1.1532161357064157e+47, 1.1532161357064157e+47, 1.1532161357064157e+47), velocities = (1, 1, 1)
#
# Step 154:
# P1 position = (-2.26076034524624e+47, -2.26076034524624e+47, -2.26076034524624e+47), velocities = (1, 1, 1)
# P2 position = (2.3064322714128315e+47, 2.3064322714128315e+47, 2.3064322714128315e+47), velocities = (1, 1, 1)
#
# Step 155:
# P1 position = (-4.52152069049248e+47, -4.52152069049248e+47, -4.52152069049248e+47), velocities = (1, 1, 1)
# P2 position = (4.612864542825663e+47, 4.612864542825663e+47, 4.612864542825663e+47), velocities = (1, 1, 1)
#
# Step 156:
# P1 position = (-9.04304138098496e+47, -9.04304138098496e+47, -9.04304138098496e+47), velocities = (1, 1, 1)
# P2 position = (9.225729085651326e+47, 9.225729085651326e+47, 9.225729085651326e+47), velocities = (1, 1, 1)
#
# Step 157:
# P1 position = (-1.808608276196992e+48, -1.808608276196992e+48, -1.808608276196992e+48), velocities = (1, 1, 1)
# P2 position = (1.8451458171302652e+48, 1.8451458171302652e+48, 1.8451458171302652e+48), velocities = (1, 1, 1)
#
# Step 158:
# P1 position = (-3.617216552393984e+48, -3.617216552393984e+48, -3.617216552393984e+48), velocities = (1, 1, 1)
# P2 position = (3.6902916342605304e+48, 3.6902916342605304e+48, 3.6902916342605304e+48), velocities = (1, 1, 1)
#
# Step 159:
# P1 position = (-7.234433104787968e+48, -7.234433104787968e+48, -7.234433104787968e+48), velocities = (1, 1, 1)
# P2 position = (7.380583268521061e+48, 7.380583268521061e+48, 7.380583268521061e+48), velocities = (1, 1, 1)
#
# Step 160:
# P1 position = (-1.4468866209575937e+49, -1.4468866209575937e+49, -1.4468866209575937e+49), velocities = (1, 1, 1)
# P2 position = (1.4761166537042122e+49, 1.4761166537042122e+49, 1.4761166537042122e+49), velocities = (1, 1, 1)
#
# Step 161:
# P1 position = (-2.8937732419151874e+49, -2.8937732419151874e+49, -2.8937732419151874e+49), velocities = (1, 1, 1)
# P2 position = (2.9522333074084243e+49, 2.9522333074084243e+49, 2.9522333074084243e+49), velocities = (1, 1, 1)
#
# Step 162:
# P1 position = (-5.787546483830375e+49, -5.787546483830375e+49, -5.787546483830375e+49), velocities = (1, 1, 1)
# P2 position = (5.904466614816849e+49, 5.904466614816849e+49, 5.904466614816849e+49), velocities = (1, 1, 1)
#
# Step 163:
# P1 position = (-1.157509296766075e+50, -1.157509296766075e+50, -1.157509296766075e+50), velocities = (1, 1, 1)
# P2 position = (1.1808933229633697e+50, 1.1808933229633697e+50, 1.1808933229633697e+50), velocities = (1, 1, 1)
#
# Step 164:
# P1 position = (-2.31501859353215e+50, -2.31501859353215e+50, -2.31501859353215e+50), velocities = (1, 1, 1)
# P2 position = (2.3617866459267394e+50, 2.3617866459267394e+50, 2.3617866459267394e+50), velocities = (1, 1, 1)
#
# Step 165:
# P1 position = (-4.6300371870643e+50, -4.6300371870643e+50, -4.6300371870643e+50), velocities = (1, 1, 1)
# P2 position = (4.723573291853479e+50, 4.723573291853479e+50, 4.723573291853479e+50), velocities = (1, 1, 1)
#
# Step 166:
# P1 position = (-9.2600743741286e+50, -9.2600743741286e+50, -9.2600743741286e+50), velocities = (1, 1, 1)
# P2 position = (9.447146583706958e+50, 9.447146583706958e+50, 9.447146583706958e+50), velocities = (1, 1, 1)
#
# Step 167:
# P1 position = (-1.85201487482572e+51, -1.85201487482572e+51, -1.85201487482572e+51), velocities = (1, 1, 1)
# P2 position = (1.8894293167413916e+51, 1.8894293167413916e+51, 1.8894293167413916e+51), velocities = (1, 1, 1)
#
# Step 168:
# P1 position = (-3.70402974965144e+51, -3.70402974965144e+51, -3.70402974965144e+51), velocities = (1, 1, 1)
# P2 position = (3.778858633482783e+51, 3.778858633482783e+51, 3.778858633482783e+51), velocities = (1, 1, 1)
#
# Step 169:
# P1 position = (-7.40805949930288e+51, -7.40805949930288e+51, -7.40805949930288e+51), velocities = (1, 1, 1)
# P2 position = (7.557717266965566e+51, 7.557717266965566e+51, 7.557717266965566e+51), velocities = (1, 1, 1)
#
# Step 170:
# P1 position = (-1.481611899860576e+52, -1.481611899860576e+52, -1.481611899860576e+52), velocities = (1, 1, 1)
# P2 position = (1.5115434533931132e+52, 1.5115434533931132e+52, 1.5115434533931132e+52), velocities = (1, 1, 1)
#
# Step 171:
# P1 position = (-2.963223799721152e+52, -2.963223799721152e+52, -2.963223799721152e+52), velocities = (1, 1, 1)
# P2 position = (3.0230869067862265e+52, 3.0230869067862265e+52, 3.0230869067862265e+52), velocities = (1, 1, 1)
#
# Step 172:
# P1 position = (-5.926447599442304e+52, -5.926447599442304e+52, -5.926447599442304e+52), velocities = (1, 1, 1)
# P2 position = (6.046173813572453e+52, 6.046173813572453e+52, 6.046173813572453e+52), velocities = (1, 1, 1)
#
# Step 173:
# P1 position = (-1.1852895198884607e+53, -1.1852895198884607e+53, -1.1852895198884607e+53), velocities = (1, 1, 1)
# P2 position = (1.2092347627144906e+53, 1.2092347627144906e+53, 1.2092347627144906e+53), velocities = (1, 1, 1)
#
# Step 174:
# P1 position = (-2.3705790397769215e+53, -2.3705790397769215e+53, -2.3705790397769215e+53), velocities = (1, 1, 1)
# P2 position = (2.418469525428981e+53, 2.418469525428981e+53, 2.418469525428981e+53), velocities = (1, 1, 1)
#
# Step 175:
# P1 position = (-4.741158079553843e+53, -4.741158079553843e+53, -4.741158079553843e+53), velocities = (1, 1, 1)
# P2 position = (4.836939050857962e+53, 4.836939050857962e+53, 4.836939050857962e+53), velocities = (1, 1, 1)
#
# Step 176:
# P1 position = (-9.482316159107686e+53, -9.482316159107686e+53, -9.482316159107686e+53), velocities = (1, 1, 1)
# P2 position = (9.673878101715925e+53, 9.673878101715925e+53, 9.673878101715925e+53), velocities = (1, 1, 1)
#
# Step 177:
# P1 position = (-1.8964632318215372e+54, -1.8964632318215372e+54, -1.8964632318215372e+54), velocities = (1, 1, 1)
# P2 position = (1.934775620343185e+54, 1.934775620343185e+54, 1.934775620343185e+54), velocities = (1, 1, 1)
#
# Step 178:
# P1 position = (-3.7929264636430744e+54, -3.7929264636430744e+54, -3.7929264636430744e+54), velocities = (1, 1, 1)
# P2 position = (3.86955124068637e+54, 3.86955124068637e+54, 3.86955124068637e+54), velocities = (1, 1, 1)
#
# Step 179:
# P1 position = (-7.585852927286149e+54, -7.585852927286149e+54, -7.585852927286149e+54), velocities = (1, 1, 1)
# P2 position = (7.73910248137274e+54, 7.73910248137274e+54, 7.73910248137274e+54), velocities = (1, 1, 1)
#
# Step 180:
# P1 position = (-1.5171705854572298e+55, -1.5171705854572298e+55, -1.5171705854572298e+55), velocities = (1, 1, 1)
# P2 position = (1.547820496274548e+55, 1.547820496274548e+55, 1.547820496274548e+55), velocities = (1, 1, 1)
#
# Step 181:
# P1 position = (-3.0343411709144595e+55, -3.0343411709144595e+55, -3.0343411709144595e+55), velocities = (1, 1, 1)
# P2 position = (3.095640992549096e+55, 3.095640992549096e+55, 3.095640992549096e+55), velocities = (1, 1, 1)
#
# Step 182:
# P1 position = (-6.068682341828919e+55, -6.068682341828919e+55, -6.068682341828919e+55), velocities = (1, 1, 1)
# P2 position = (6.191281985098192e+55, 6.191281985098192e+55, 6.191281985098192e+55), velocities = (1, 1, 1)
#
# Step 183:
# P1 position = (-1.2137364683657838e+56, -1.2137364683657838e+56, -1.2137364683657838e+56), velocities = (1, 1, 1)
# P2 position = (1.2382563970196384e+56, 1.2382563970196384e+56, 1.2382563970196384e+56), velocities = (1, 1, 1)
#
# Step 184:
# P1 position = (-2.4274729367315676e+56, -2.4274729367315676e+56, -2.4274729367315676e+56), velocities = (1, 1, 1)
# P2 position = (2.4765127940392767e+56, 2.4765127940392767e+56, 2.4765127940392767e+56), velocities = (1, 1, 1)
#
# Step 185:
# P1 position = (-4.854945873463135e+56, -4.854945873463135e+56, -4.854945873463135e+56), velocities = (1, 1, 1)
# P2 position = (4.9530255880785535e+56, 4.9530255880785535e+56, 4.9530255880785535e+56), velocities = (1, 1, 1)
#
# Step 186:
# P1 position = (-9.70989174692627e+56, -9.70989174692627e+56, -9.70989174692627e+56), velocities = (1, 1, 1)
# P2 position = (9.906051176157107e+56, 9.906051176157107e+56, 9.906051176157107e+56), velocities = (1, 1, 1)
#
# Step 187:
# P1 position = (-1.941978349385254e+57, -1.941978349385254e+57, -1.941978349385254e+57), velocities = (1, 1, 1)
# P2 position = (1.9812102352314214e+57, 1.9812102352314214e+57, 1.9812102352314214e+57), velocities = (1, 1, 1)
#
# Step 188:
# P1 position = (-3.883956698770508e+57, -3.883956698770508e+57, -3.883956698770508e+57), velocities = (1, 1, 1)
# P2 position = (3.962420470462843e+57, 3.962420470462843e+57, 3.962420470462843e+57), velocities = (1, 1, 1)
#
# Step 189:
# P1 position = (-7.767913397541016e+57, -7.767913397541016e+57, -7.767913397541016e+57), velocities = (1, 1, 1)
# P2 position = (7.924840940925686e+57, 7.924840940925686e+57, 7.924840940925686e+57), velocities = (1, 1, 1)
#
# Step 190:
# P1 position = (-1.5535826795082033e+58, -1.5535826795082033e+58, -1.5535826795082033e+58), velocities = (1, 1, 1)
# P2 position = (1.584968188185137e+58, 1.584968188185137e+58, 1.584968188185137e+58), velocities = (1, 1, 1)
#
# Step 191:
# P1 position = (-3.1071653590164065e+58, -3.1071653590164065e+58, -3.1071653590164065e+58), velocities = (1, 1, 1)
# P2 position = (3.169936376370274e+58, 3.169936376370274e+58, 3.169936376370274e+58), velocities = (1, 1, 1)
#
# Step 192:
# P1 position = (-6.214330718032813e+58, -6.214330718032813e+58, -6.214330718032813e+58), velocities = (1, 1, 1)
# P2 position = (6.339872752740548e+58, 6.339872752740548e+58, 6.339872752740548e+58), velocities = (1, 1, 1)
#
# Step 193:
# P1 position = (-1.2428661436065626e+59, -1.2428661436065626e+59, -1.2428661436065626e+59), velocities = (1, 1, 1)
# P2 position = (1.2679745505481097e+59, 1.2679745505481097e+59, 1.2679745505481097e+59), velocities = (1, 1, 1)
#
# Step 194:
# P1 position = (-2.4857322872131252e+59, -2.4857322872131252e+59, -2.4857322872131252e+59), velocities = (1, 1, 1)
# P2 position = (2.5359491010962194e+59, 2.5359491010962194e+59, 2.5359491010962194e+59), velocities = (1, 1, 1)
#
# Step 195:
# P1 position = (-4.9714645744262505e+59, -4.9714645744262505e+59, -4.9714645744262505e+59), velocities = (1, 1, 1)
# P2 position = (5.071898202192439e+59, 5.071898202192439e+59, 5.071898202192439e+59), velocities = (1, 1, 1)
#
# Step 196:
# P1 position = (-9.942929148852501e+59, -9.942929148852501e+59, -9.942929148852501e+59), velocities = (1, 1, 1)
# P2 position = (1.0143796404384878e+60, 1.0143796404384878e+60, 1.0143796404384878e+60), velocities = (1, 1, 1)
#
# Step 197:
# P1 position = (-1.9885858297705002e+60, -1.9885858297705002e+60, -1.9885858297705002e+60), velocities = (1, 1, 1)
# P2 position = (2.0287592808769755e+60, 2.0287592808769755e+60, 2.0287592808769755e+60), velocities = (1, 1, 1)
#
# Step 198:
# P1 position = (-3.9771716595410004e+60, -3.9771716595410004e+60, -3.9771716595410004e+60), velocities = (1, 1, 1)
# P2 position = (4.057518561753951e+60, 4.057518561753951e+60, 4.057518561753951e+60), velocities = (1, 1, 1)
#
# Step 199:
# P1 position = (-7.954343319082001e+60, -7.954343319082001e+60, -7.954343319082001e+60), velocities = (1, 1, 1)
# P2 position = (8.115037123507902e+60, 8.115037123507902e+60, 8.115037123507902e+60), velocities = (1, 1, 1)
#
# Step 200:
# P1 position = (-1.5908686638164001e+61, -1.5908686638164001e+61, -1.5908686638164001e+61), velocities = (1, 1, 1)
# P2 position = (1.6230074247015804e+61, 1.6230074247015804e+61, 1.6230074247015804e+61), velocities = (1, 1, 1)
#
# Step 201:
# P1 position = (-3.1817373276328003e+61, -3.1817373276328003e+61, -3.1817373276328003e+61), velocities = (1, 1, 1)
# P2 position = (3.246014849403161e+61, 3.246014849403161e+61, 3.246014849403161e+61), velocities = (1, 1, 1)
#
# Step 202:
# P1 position = (-6.363474655265601e+61, -6.363474655265601e+61, -6.363474655265601e+61), velocities = (1, 1, 1)
# P2 position = (6.492029698806322e+61, 6.492029698806322e+61, 6.492029698806322e+61), velocities = (1, 1, 1)
#
# Step 203:
# P1 position = (-1.2726949310531201e+62, -1.2726949310531201e+62, -1.2726949310531201e+62), velocities = (1, 1, 1)
# P2 position = (1.2984059397612643e+62, 1.2984059397612643e+62, 1.2984059397612643e+62), velocities = (1, 1, 1)
#
# Step 204:
# P1 position = (-2.5453898621062402e+62, -2.5453898621062402e+62, -2.5453898621062402e+62), velocities = (1, 1, 1)
# P2 position = (2.5968118795225287e+62, 2.5968118795225287e+62, 2.5968118795225287e+62), velocities = (1, 1, 1)
#
# Step 205:
# P1 position = (-5.0907797242124805e+62, -5.0907797242124805e+62, -5.0907797242124805e+62), velocities = (1, 1, 1)
# P2 position = (5.193623759045057e+62, 5.193623759045057e+62, 5.193623759045057e+62), velocities = (1, 1, 1)
#
# Step 206:
# P1 position = (-1.0181559448424961e+63, -1.0181559448424961e+63, -1.0181559448424961e+63), velocities = (1, 1, 1)
# P2 position = (1.0387247518090115e+63, 1.0387247518090115e+63, 1.0387247518090115e+63), velocities = (1, 1, 1)
#
# Step 207:
# P1 position = (-2.0363118896849922e+63, -2.0363118896849922e+63, -2.0363118896849922e+63), velocities = (1, 1, 1)
# P2 position = (2.077449503618023e+63, 2.077449503618023e+63, 2.077449503618023e+63), velocities = (1, 1, 1)
#
# Step 208:
# P1 position = (-4.0726237793699844e+63, -4.0726237793699844e+63, -4.0726237793699844e+63), velocities = (1, 1, 1)
# P2 position = (4.154899007236046e+63, 4.154899007236046e+63, 4.154899007236046e+63), velocities = (1, 1, 1)
#
# Step 209:
# P1 position = (-8.145247558739969e+63, -8.145247558739969e+63, -8.145247558739969e+63), velocities = (1, 1, 1)
# P2 position = (8.309798014472092e+63, 8.309798014472092e+63, 8.309798014472092e+63), velocities = (1, 1, 1)
#
# Step 210:
# P1 position = (-1.6290495117479937e+64, -1.6290495117479937e+64, -1.6290495117479937e+64), velocities = (1, 1, 1)
# P2 position = (1.6619596028944183e+64, 1.6619596028944183e+64, 1.6619596028944183e+64), velocities = (1, 1, 1)
#
# Step 211:
# P1 position = (-3.2580990234959875e+64, -3.2580990234959875e+64, -3.2580990234959875e+64), velocities = (1, 1, 1)
# P2 position = (3.3239192057888367e+64, 3.3239192057888367e+64, 3.3239192057888367e+64), velocities = (1, 1, 1)
#
# Step 212:
# P1 position = (-6.516198046991975e+64, -6.516198046991975e+64, -6.516198046991975e+64), velocities = (1, 1, 1)
# P2 position = (6.647838411577673e+64, 6.647838411577673e+64, 6.647838411577673e+64), velocities = (1, 1, 1)
#
# Step 213:
# P1 position = (-1.303239609398395e+65, -1.303239609398395e+65, -1.303239609398395e+65), velocities = (1, 1, 1)
# P2 position = (1.3295676823155347e+65, 1.3295676823155347e+65, 1.3295676823155347e+65), velocities = (1, 1, 1)
#
# Step 214:
# ...
# P1 position = (-6.763711419854753e+70, -6.763711419854753e+70, -6.763711419854753e+70), velocities = (2, 2, 2)
# P2 position = (6.832728883322657e+70, 6.832728883322657e+70, 6.832728883322657e+70), velocities = (-1, -1, -1)
#
# Step 233:
# P1 position = (-1.3527422839709506e+71, -1.3527422839709506e+71, -1.3527422839709506e+71), velocities = (2, 2, 2)
# P2 position = (1.3665457766645314e+71, 1.3665457766645314e+71, 1.3665457766645314e+71), velocities = (-1, -1, -1)
#
# Step 234:
# P1 position = (-2.705484567941901e+71, -2.705484567941901e+71, -2.705484567941901e+71), velocities = (2, 2, 2)
# P2 position = (2.733091553329063e+71, 2.733091553329063e+71, 2.733091553329063e+71), velocities = (-1, -1, -1)
#
# Step 235:
# P1 position = (-5.410969135883802e+71, -5.410969135883802e+71, -5.410969135883802e+71), velocities = (2, 2, 2)
# P2 position = (5.466183106658126e+71, 5.466183106658126e+71, 5.466183106658126e+71), velocities = (-1, -1, -1)
#
# Step 236:
# P1 position = (-1.0821938271767605e+72, -1.0821938271767605e+72, -1.0821938271767605e+72), velocities = (2, 2, 2)
# P2 position = (1.0932366213316251e+72, 1.0932366213316251e+72, 1.0932366213316251e+72), velocities = (-1, -1, -1)
#
# Step 237:
# P1 position = (-2.164387654353521e+72, -2.164387654353521e+72, -2.164387654353521e+72), velocities = (2, 2, 2)
# P2 position = (2.1864732426632503e+72, 2.1864732426632503e+72, 2.1864732426632503e+72), velocities = (-1, -1, -1)
#
# Step 238:
# P1 position = (-4.328775308707042e+72, -4.328775308707042e+72, -4.328775308707042e+72), velocities = (2, 2, 2)
# P2 position = (4.3729464853265006e+72, 4.3729464853265006e+72, 4.3729464853265006e+72), velocities = (-1, -1, -1)
#
# Step 239:
# P1 position = (-8.657550617414084e+72, -8.657550617414084e+72, -8.657550617414084e+72), velocities = (2, 2, 2)
# P2 position = (8.745892970653001e+72, 8.745892970653001e+72, 8.745892970653001e+72), velocities = (-1, -1, -1)
#
# Step 240:
# P1 position = (-1.7315101234828168e+73, -1.7315101234828168e+73, -1.7315101234828168e+73), velocities = (2, 2, 2)
# P2 position = (1.7491785941306002e+73, 1.7491785941306002e+73, 1.7491785941306002e+73), velocities = (-1, -1, -1)
#
# Step 241:
# P1 position = (-3.4630202469656335e+73, -3.4630202469656335e+73, -3.4630202469656335e+73), velocities = (2, 2, 2)
# P2 position = (3.4983571882612005e+73, 3.4983571882612005e+73, 3.4983571882612005e+73), velocities = (-1, -1, -1)
#
# Step 242:
# P1 position = (-6.926040493931267e+73, -6.926040493931267e+73, -6.926040493931267e+73), velocities = (2, 2, 2)
# P2 position = (6.996714376522401e+73, 6.996714376522401e+73, 6.996714376522401e+73), velocities = (-1, -1, -1)
#
# Step 243:
# P1 position = (-1.3852080987862534e+74, -1.3852080987862534e+74, -1.3852080987862534e+74), velocities = (2, 2, 2)
# P2 position = (1.3993428753044802e+74, 1.3993428753044802e+74, 1.3993428753044802e+74), velocities = (-1, -1, -1)
#
# Step 244:
# P1 position = (-2.770416197572507e+74, -2.770416197572507e+74, -2.770416197572507e+74), velocities = (2, 2, 2)
# P2 position = (2.7986857506089604e+74, 2.7986857506089604e+74, 2.7986857506089604e+74), velocities = (-1, -1, -1)
#
# Step 245:
# P1 position = (-5.540832395145014e+74, -5.540832395145014e+74, -5.540832395145014e+74), velocities = (2, 2, 2)
# P2 position = (5.597371501217921e+74, 5.597371501217921e+74, 5.597371501217921e+74), velocities = (-1, -1, -1)
#
# Step 246:
# P1 position = (-1.1081664790290027e+75, -1.1081664790290027e+75, -1.1081664790290027e+75), velocities = (2, 2, 2)
# P2 position = (1.1194743002435842e+75, 1.1194743002435842e+75, 1.1194743002435842e+75), velocities = (-1, -1, -1)
#
# Step 247:
# P1 position = (-2.2163329580580055e+75, -2.2163329580580055e+75, -2.2163329580580055e+75), velocities = (2, 2, 2)
# P2 position = (2.2389486004871683e+75, 2.2389486004871683e+75, 2.2389486004871683e+75), velocities = (-1, -1, -1)
#
# Step 248:
# P1 position = (-4.432665916116011e+75, -4.432665916116011e+75, -4.432665916116011e+75), velocities = (2, 2, 2)
# P2 position = (4.477897200974337e+75, 4.477897200974337e+75, 4.477897200974337e+75), velocities = (-1, -1, -1)
#
# Step 249:
# P1 position = (-8.865331832232022e+75, -8.865331832232022e+75, -8.865331832232022e+75), velocities = (2, 2, 2)
# P2 position = (8.955794401948673e+75, 8.955794401948673e+75, 8.955794401948673e+75), velocities = (-1, -1, -1)
#
# Step 250:
# P1 position = (-1.7730663664464044e+76, -1.7730663664464044e+76, -1.7730663664464044e+76), velocities = (2, 2, 2)
# P2 position = (1.7911588803897346e+76, 1.7911588803897346e+76, 1.7911588803897346e+76), velocities = (-1, -1, -1)
#
# Step 251:
# P1 position = (-3.546132732892809e+76, -3.546132732892809e+76, -3.546132732892809e+76), velocities = (2, 2, 2)
# P2 position = (3.582317760779469e+76, 3.582317760779469e+76, 3.582317760779469e+76), velocities = (-1, -1, -1)
#
# Step 252:
# P1 position = (-7.092265465785617e+76, -7.092265465785617e+76, -7.092265465785617e+76), velocities = (2, 2, 2)
# P2 position = (7.164635521558939e+76, 7.164635521558939e+76, 7.164635521558939e+76), velocities = (-1, -1, -1)
#
# Step 253:
# P1 position = (-1.4184530931571235e+77, -1.4184530931571235e+77, -1.4184530931571235e+77), velocities = (2, 2, 2)
# P2 position = (1.4329271043117877e+77, 1.4329271043117877e+77, 1.4329271043117877e+77), velocities = (-1, -1, -1)
#
# Step 254:
# P1 position = (-2.836906186314247e+77, -2.836906186314247e+77, -2.836906186314247e+77), velocities = (2, 2, 2)
# P2 position = (2.8658542086235754e+77, 2.8658542086235754e+77, 2.8658542086235754e+77), velocities = (-1, -1, -1)
#
# Step 255:
# P1 position = (-5.673812372628494e+77, -5.673812372628494e+77, -5.673812372628494e+77), velocities = (2, 2, 2)
# P2 position = (5.731708417247151e+77, 5.731708417247151e+77, 5.731708417247151e+77), velocities = (-1, -1, -1)
#
# Step 256:
# P1 position = (-1.1347624745256988e+78, -1.1347624745256988e+78, -1.1347624745256988e+78), velocities = (2, 2, 2)
# P2 position = (1.1463416834494302e+78, 1.1463416834494302e+78, 1.1463416834494302e+78), velocities = (-1, -1, -1)
#
# Step 257:
# P1 position = (-2.2695249490513976e+78, -2.2695249490513976e+78, -2.2695249490513976e+78), velocities = (2, 2, 2)
# P2 position = (2.2926833668988603e+78, 2.2926833668988603e+78, 2.2926833668988603e+78), velocities = (-1, -1, -1)
#
# Step 258:
# P1 position = (-4.539049898102795e+78, -4.539049898102795e+78, -4.539049898102795e+78), velocities = (2, 2, 2)
# P2 position = (4.585366733797721e+78, 4.585366733797721e+78, 4.585366733797721e+78), velocities = (-1, -1, -1)
#
# Step 259:
# P1 position = (-9.07809979620559e+78, -9.07809979620559e+78, -9.07809979620559e+78), velocities = (2, 2, 2)
# P2 position = (9.170733467595441e+78, 9.170733467595441e+78, 9.170733467595441e+78), velocities = (-1, -1, -1)
#
# Step 260:
# P1 position = (-1.815619959241118e+79, -1.815619959241118e+79, -1.815619959241118e+79), velocities = (2, 2, 2)
# P2 position = (1.8341466935190883e+79, 1.8341466935190883e+79, 1.8341466935190883e+79), velocities = (-1, -1, -1)
#
# Step 261:
# P1 position = (-3.631239918482236e+79, -3.631239918482236e+79, -3.631239918482236e+79), velocities = (2, 2, 2)
# P2 position = (3.6682933870381765e+79, 3.6682933870381765e+79, 3.6682933870381765e+79), velocities = (-1, -1, -1)
#
# Step 262:
# P1 position = (-7.262479836964472e+79, -7.262479836964472e+79, -7.262479836964472e+79), velocities = (2, 2, 2)
# P2 position = (7.336586774076353e+79, 7.336586774076353e+79, 7.336586774076353e+79), velocities = (-1, -1, -1)
#
# Step 263:
# P1 position = (-1.4524959673928945e+80, -1.4524959673928945e+80, -1.4524959673928945e+80), velocities = (2, 2, 2)
# P2 position = (1.4673173548152706e+80, 1.4673173548152706e+80, 1.4673173548152706e+80), velocities = (-1, -1, -1)
#
# Step 264:
# P1 position = (-2.904991934785789e+80, -2.904991934785789e+80, -2.904991934785789e+80), velocities = (2, 2, 2)
# P2 position = (2.934634709630541e+80, 2.934634709630541e+80, 2.934634709630541e+80), velocities = (-1, -1, -1)
#
# Step 265:
# P1 position = (-5.809983869571578e+80, -5.809983869571578e+80, -5.809983869571578e+80), velocities = (2, 2, 2)
# P2 position = (5.869269419261082e+80, 5.869269419261082e+80, 5.869269419261082e+80), velocities = (-1, -1, -1)
#
# Step 266:
# P1 position = (-1.1619967739143156e+81, -1.1619967739143156e+81, -1.1619967739143156e+81), velocities = (2, 2, 2)
# P2 position = (1.1738538838522165e+81, 1.1738538838522165e+81, 1.1738538838522165e+81), velocities = (-1, -1, -1)
#
# Step 267:
# P1 position = (-2.323993547828631e+81, -2.323993547828631e+81, -2.323993547828631e+81), velocities = (2, 2, 2)
# P2 position = (2.347707767704433e+81, 2.347707767704433e+81, 2.347707767704433e+81), velocities = (-1, -1, -1)
#
# Step 268:
# P1 position = (-4.647987095657262e+81, -4.647987095657262e+81, -4.647987095657262e+81), velocities = (2, 2, 2)
# P2 position = (4.695415535408866e+81, 4.695415535408866e+81, 4.695415535408866e+81), velocities = (-1, -1, -1)
#
# Step 269:
# P1 position = (-9.295974191314525e+81, -9.295974191314525e+81, -9.295974191314525e+81), velocities = (2, 2, 2)
# P2 position = (9.390831070817732e+81, 9.390831070817732e+81, 9.390831070817732e+81), velocities = (-1, -1, -1)
#
# Step 270:
# P1 position = (-1.859194838262905e+82, -1.859194838262905e+82, -1.859194838262905e+82), velocities = (2, 2, 2)
# P2 position = (1.8781662141635464e+82, 1.8781662141635464e+82, 1.8781662141635464e+82), velocities = (-1, -1, -1)
#
# Step 271:
# P1 position = (-3.71838967652581e+82, -3.71838967652581e+82, -3.71838967652581e+82), velocities = (2, 2, 2)
# P2 position = (3.756332428327093e+82, 3.756332428327093e+82, 3.756332428327093e+82), velocities = (-1, -1, -1)
#
# Step 272:
# P1 position = (-7.43677935305162e+82, -7.43677935305162e+82, -7.43677935305162e+82), velocities = (2, 2, 2)
# P2 position = (7.512664856654186e+82, 7.512664856654186e+82, 7.512664856654186e+82), velocities = (-1, -1, -1)
#
# Step 273:
# P1 position = (-1.487355870610324e+83, -1.487355870610324e+83, -1.487355870610324e+83), velocities = (2, 2, 2)
# P2 position = (1.502532971330837e+83, 1.502532971330837e+83, 1.502532971330837e+83), velocities = (-1, -1, -1)
#
# Step 274:
# P1 position = (-2.974711741220648e+83, -2.974711741220648e+83, -2.974711741220648e+83), velocities = (2, 2, 2)
# P2 position = (3.005065942661674e+83, 3.005065942661674e+83, 3.005065942661674e+83), velocities = (-1, -1, -1)
#
# Step 275:
# P1 position = (-5.949423482441296e+83, -5.949423482441296e+83, -5.949423482441296e+83), velocities = (2, 2, 2)
# P2 position = (6.010131885323348e+83, 6.010131885323348e+83, 6.010131885323348e+83), velocities = (-1, -1, -1)
#
# Step 276:
# P1 position = (-1.1898846964882591e+84, -1.1898846964882591e+84, -1.1898846964882591e+84), velocities = (2, 2, 2)
# P2 position = (1.2020263770646697e+84, 1.2020263770646697e+84, 1.2020263770646697e+84), velocities = (-1, -1, -1)
#
# Step 277:
# P1 position = (-2.3797693929765183e+84, -2.3797693929765183e+84, -2.3797693929765183e+84), velocities = (2, 2, 2)
# P2 position = (2.4040527541293394e+84, 2.4040527541293394e+84, 2.4040527541293394e+84), velocities = (-1, -1, -1)
#
# Step 278:
# P1 position = (-4.759538785953037e+84, -4.759538785953037e+84, -4.759538785953037e+84), velocities = (2, 2, 2)
# P2 position = (4.808105508258679e+84, 4.808105508258679e+84, 4.808105508258679e+84), velocities = (-1, -1, -1)
#
# Step 279:
# P1 position = (-9.519077571906073e+84, -9.519077571906073e+84, -9.519077571906073e+84), velocities = (2, 2, 2)
# P2 position = (9.616211016517358e+84, 9.616211016517358e+84, 9.616211016517358e+84), velocities = (-1, -1, -1)
#
# Step 280:
# P1 position = (-1.9038155143812146e+85, -1.9038155143812146e+85, -1.9038155143812146e+85), velocities = (2, 2, 2)
# P2 position = (1.9232422033034715e+85, 1.9232422033034715e+85, 1.9232422033034715e+85), velocities = (-1, -1, -1)
#
# Step 281:
# P1 position = (-3.807631028762429e+85, -3.807631028762429e+85, -3.807631028762429e+85), velocities = (2, 2, 2)
# P2 position = (3.846484406606943e+85, 3.846484406606943e+85, 3.846484406606943e+85), velocities = (-1, -1, -1)
#
# Step 282:
# P1 position = (-7.615262057524859e+85, -7.615262057524859e+85, -7.615262057524859e+85), velocities = (2, 2, 2)
# P2 position = (7.692968813213886e+85, 7.692968813213886e+85, 7.692968813213886e+85), velocities = (-1, -1, -1)
#
# Step 283:
# P1 position = (-1.5230524115049717e+86, -1.5230524115049717e+86, -1.5230524115049717e+86), velocities = (2, 2, 2)
# P2 position = (1.5385937626427772e+86, 1.5385937626427772e+86, 1.5385937626427772e+86), velocities = (-1, -1, -1)
#
# Step 284:
# P1 position = (-3.0461048230099434e+86, -3.0461048230099434e+86, -3.0461048230099434e+86), velocities = (2, 2, 2)
# P2 position = (3.0771875252855544e+86, 3.0771875252855544e+86, 3.0771875252855544e+86), velocities = (-1, -1, -1)
#
# Step 285:
# P1 position = (-6.092209646019887e+86, -6.092209646019887e+86, -6.092209646019887e+86), velocities = (2, 2, 2)
# P2 position = (6.154375050571109e+86, 6.154375050571109e+86, 6.154375050571109e+86), velocities = (-1, -1, -1)
#
# Step 286:
# P1 position = (-1.2184419292039774e+87, -1.2184419292039774e+87, -1.2184419292039774e+87), velocities = (2, 2, 2)
# P2 position = (1.2308750101142218e+87, 1.2308750101142218e+87, 1.2308750101142218e+87), velocities = (-1, -1, -1)
#
# Step 287:
# P1 position = (-2.4368838584079547e+87, -2.4368838584079547e+87, -2.4368838584079547e+87), velocities = (2, 2, 2)
# P2 position = (2.4617500202284435e+87, 2.4617500202284435e+87, 2.4617500202284435e+87), velocities = (-1, -1, -1)
#
# Step 288:
# P1 position = (-4.8737677168159094e+87, -4.8737677168159094e+87, -4.8737677168159094e+87), velocities = (2, 2, 2)
# P2 position = (4.923500040456887e+87, 4.923500040456887e+87, 4.923500040456887e+87), velocities = (-1, -1, -1)
#
# Step 289:
# P1 position = (-9.747535433631819e+87, -9.747535433631819e+87, -9.747535433631819e+87), velocities = (2, 2, 2)
# P2 position = (9.847000080913774e+87, 9.847000080913774e+87, 9.847000080913774e+87), velocities = (-1, -1, -1)
#
# Step 290:
# P1 position = (-1.9495070867263638e+88, -1.9495070867263638e+88, -1.9495070867263638e+88), velocities = (2, 2, 2)
# P2 position = (1.9694000161827548e+88, 1.9694000161827548e+88, 1.9694000161827548e+88), velocities = (-1, -1, -1)
#
# Step 291:
# P1 position = (-3.8990141734527276e+88, -3.8990141734527276e+88, -3.8990141734527276e+88), velocities = (2, 2, 2)
# P2 position = (3.9388000323655096e+88, 3.9388000323655096e+88, 3.9388000323655096e+88), velocities = (-1, -1, -1)
#
# Step 292:
# P1 position = (-7.798028346905455e+88, -7.798028346905455e+88, -7.798028346905455e+88), velocities = (2, 2, 2)
# P2 position = (7.877600064731019e+88, 7.877600064731019e+88, 7.877600064731019e+88), velocities = (-1, -1, -1)
#
# Step 293:
# P1 position = (-1.559605669381091e+89, -1.559605669381091e+89, -1.559605669381091e+89), velocities = (2, 2, 2)
# P2 position = (1.5755200129462039e+89, 1.5755200129462039e+89, 1.5755200129462039e+89), velocities = (-1, -1, -1)
#
# Step 294:
# P1 position = (-3.119211338762182e+89, -3.119211338762182e+89, -3.119211338762182e+89), velocities = (2, 2, 2)
# P2 position = (3.1510400258924077e+89, 3.1510400258924077e+89, 3.1510400258924077e+89), velocities = (-1, -1, -1)
#
# Step 295:
# P1 position = (-6.238422677524364e+89, -6.238422677524364e+89, -6.238422677524364e+89), velocities = (2, 2, 2)
# P2 position = (6.302080051784815e+89, 6.302080051784815e+89, 6.302080051784815e+89), velocities = (-1, -1, -1)
#
# Step 296:
# P1 position = (-1.2476845355048728e+90, -1.2476845355048728e+90, -1.2476845355048728e+90), velocities = (2, 2, 2)
# P2 position = (1.260416010356963e+90, 1.260416010356963e+90, 1.260416010356963e+90), velocities = (-1, -1, -1)
#
# Step 297:
# P1 position = (-2.4953690710097456e+90, -2.4953690710097456e+90, -2.4953690710097456e+90), velocities = (2, 2, 2)
# P2 position = (2.520832020713926e+90, 2.520832020713926e+90, 2.520832020713926e+90), velocities = (-1, -1, -1)
#
# Step 298:
# P1 position = (-4.990738142019491e+90, -4.990738142019491e+90, -4.990738142019491e+90), velocities = (2, 2, 2)
# P2 position = (5.041664041427852e+90, 5.041664041427852e+90, 5.041664041427852e+90), velocities = (-1, -1, -1)
#
# Step 299:
# P1 position = (-9.981476284038983e+90, -9.981476284038983e+90, -9.981476284038983e+90), velocities = (2, 2, 2)
# P2 position = (1.0083328082855705e+91, 1.0083328082855705e+91, 1.0083328082855705e+91), velocities = (-1, -1, -1)
